# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPool2D, Flatten, Dropout, Dense
from tensorflow.keras.optimizers import Adam

# %%
data_path = r'C:\Users\anagh\Downloads\DD'
spiral_train_path = os.path.join(data_path, 'spiral', 'spiral', 'training')

# %%
def load_images_from_directory(directory, img_size=(128, 128)):
    images = []
    labels = []
    for label in os.listdir(directory):
        label_dir = os.path.join(directory, label)
        if os.path.isdir(label_dir):
            for file in os.listdir(label_dir):
                file_path = os.path.join(label_dir, file)
                if file_path.endswith('.png') or file_path.endswith('.jpg'):
                    image = cv2.imread(file_path)
                    image = cv2.resize(image, img_size)  # Resize image to img_size
                    images.append(image)
                    labels.append(label)
    return np.array(images), np.array(labels)

# %%
x_train, y_train = load_images_from_directory(spiral_train_path)

print(f"x_train shape: {x_train.shape}")
print(f"y_train shape: {y_train.shape}")
# Out:
# x_train shape: (72, 128, 128, 3)
# y_train shape: (72,)

# %%
# Splitting the data into train and test sets
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.2, stratify=y_train, random_state=42)

# %%
# Data Distribution
unique_train, count_train = np.unique(y_train, return_counts=True)
plt.figure(figsize=(20, 10))
sns.barplot(x=unique_train, y=count_train).set_title("Number of training images per category:")
plt.show()

# %%
unique_test, count_test = np.unique(y_test, return_counts=True)
plt.figure(figsize=(20, 10))
sns.barplot(x=unique_test, y=count_test).set_title("Number of testing images per category:")
plt.show()

# %%
# Augmenting the Dataset
train_data_generator = ImageDataGenerator(rotation_range=360, horizontal_flip=True, vertical_flip=True)

x_aug_train = []
y_aug_train = []

for (i, v) in enumerate(y_train):
    x_img = x_train[i]
    x_img = np.expand_dims(x_img, axis=0)
    aug_iter = train_data_generator.flow(x_img, batch_size=1, shuffle=True)
    for j in range(70):
        aug_image = next(aug_iter)[0].astype('uint8')
        x_aug_train.append(aug_image)
        y_aug_train.append(v)

x_train = np.concatenate((x_train, np.array(x_aug_train)), axis=0)
y_train = np.concatenate((y_train, np.array(y_aug_train)), axis=0)

print(f"x_train shape after augmentation: {x_train.shape}")
print(f"y_train shape after augmentation: {y_train.shape}")
# Out:
# x_train shape after augmentation: (4047, 128, 128, 3)
# y_train shape after augmentation: (4047,)

# %%
# Preprocessing the Images
x_train = np.array([cv2.cvtColor(cv2.resize(img, (128, 128)), cv2.COLOR_BGR2GRAY) for img in x_train])
x_test = np.array([cv2.cvtColor(cv2.resize(img, (128, 128)), cv2.COLOR_BGR2GRAY) for img in x_test])

x_train = x_train / 255.0
x_test = x_test / 255.0

label_encoder = LabelEncoder()
y_train = to_categorical(label_encoder.fit_transform(y_train))
y_test = to_categorical(label_encoder.transform(y_test))

x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

print(f"x_train shape after preprocessing: {x_train.shape}")
print(f"y_train shape after preprocessing: {y_train.shape}")
print(f"x_test shape after preprocessing: {x_test.shape}")
print(f"y_test shape after preprocessing: {y_test.shape}")
# Out:
# x_train shape after preprocessing: (4047, 128, 128, 1)
# y_train shape after preprocessing: (4047, 2)
# x_test shape after preprocessing: (15, 128, 128, 1)
# y_test shape after preprocessing: (15, 2)

# %%
# Define the Model
def parkinson_disease_detection_model(input_shape=(128, 128, 1)):
    regularizer = tf.keras.regularizers.l2(0.001)
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(Conv2D(128, (5, 5), padding='same', strides=(1, 1), name='conv1', activation='relu', kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((9, 9), strides=(3, 3)))
    model.add(Conv2D(64, (5, 5), padding='same', strides=(1, 1), name='conv2', activation='relu', kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((7, 7), strides=(3, 3)))
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv3', activation='relu', kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((5, 5), strides=(2, 2)))
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv4', activation='relu', kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((3, 3), strides=(2, 2)))
    model.add(Flatten())
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu', kernel_initializer='glorot_uniform', name='fc1'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax', kernel_initializer='glorot_uniform', name='fc3'))
    optimizer = Adam(3.15e-5)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

model = parkinson_disease_detection_model(input_shape=(128, 128, 1))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1 (Conv2D)                       │ (None, 128, 128, 128)       │           3,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 40, 40, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2 (Conv2D)                       │ (None, 40, 40, 64)          │         204,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 12, 12, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv3 (Conv2D)                       │ (None, 12, 12, 32)          │          18,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv4 (Conv2D)                       │ (None, 4, 4, 32)            │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 1, 1, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ fc1 (Dense)                          │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ fc3 (Dense)                          │ (None, 2)                   │             130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 238,146 (930.26 KB)
#  Trainable params: 238,146 (930.26 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Training the Model
hist = model.fit(x_train, y_train, batch_size=128, epochs=70, validation_data=(x_test, y_test))
# Out:
# Epoch 1/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 115s 3s/step - accuracy: 0.5124 - loss: 0.8544 - val_accuracy: 0.5333 - val_loss: 0.8479
# Epoch 2/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 110s 3s/step - accuracy: 0.5037 - loss: 0.8474 - val_accuracy: 0.5333 - val_loss: 0.8416
# Epoch 3/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 110s 3s/step - accuracy: 0.5096 - loss: 0.8405 - val_accuracy: 0.4667 - val_loss: 0.8366
# Epoch 4/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 118s 4s/step - accuracy: 0.5043 - loss: 0.8351 - val_accuracy: 0.4667 - val_loss: 0.8312
# Epoch 5/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 115s 4s/step - accuracy: 0.4990 - loss: 0.8297 - val_accuracy: 0.5333 - val_loss: 0.8253
# Epoch 6/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 110s 3s/step - accuracy: 0.4993 - loss: 0.8242 - val_accuracy: 0.4667 - val_loss: 0.8204
# Epoch 7/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 112s 3s/step - accuracy: 0.5050 - loss: 0.8193 - val_accuracy: 0.4667 - val_loss: 0.8159
# Epoch 8/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 138s 3s/step - accuracy: 0.5042 - loss: 0.8152 - val_accuracy: 0.5333 - val_loss: 0.8111
# Epoch 9/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 109s 3s/step - accuracy: 0.5167 - loss: 0.8094 - val_accuracy: 0.4667 - val_loss: 0.8073
# Epoch 10/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 142s 3s/step - accuracy: 0.4967 - loss: 0.8071 - val_accuracy: 0.4667 - val_loss: 0.8038
# Epoch 11/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.5207 - loss: 0.8022 - val_accuracy: 0.5333 - val_loss: 0.7991
# Epoch 12/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 851ms/step - accuracy: 0.5115 - loss: 0.7985 - val_accuracy: 0.7333 - val_loss: 0.7953
# Epoch 13/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.5198 - loss: 0.7948 - val_accuracy: 0.4667 - val_loss: 0.7936
# Epoch 14/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.5341 - loss: 0.7914 - val_accuracy: 0.4667 - val_loss: 0.7907
# Epoch 15/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.5306 - loss: 0.7881 - val_accuracy: 0.4667 - val_loss: 0.7868
# Epoch 16/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.5268 - loss: 0.7851 - val_accuracy: 0.4667 - val_loss: 0.7834
# Epoch 17/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.5511 - loss: 0.7817 - val_accuracy: 0.4667 - val_loss: 0.7843
# Epoch 18/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.5182 - loss: 0.7793 - val_accuracy: 0.4667 - val_loss: 0.7785
# Epoch 19/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.5497 - loss: 0.7760 - val_accuracy: 0.6000 - val_loss: 0.7739
# Epoch 20/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.5485 - loss: 0.7732 - val_accuracy: 0.6000 - val_loss: 0.7716
# Epoch 21/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.5431 - loss: 0.7707 - val_accuracy: 0.4667 - val_loss: 0.7714
# Epoch 22/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 32s 993ms/step - accuracy: 0.5635 - loss: 0.7662 - val_accuracy: 0.6000 - val_loss: 0.7642
# Epoch 23/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 957ms/step - accuracy: 0.5791 - loss: 0.7632 - val_accuracy: 0.8000 - val_loss: 0.7604
# Epoch 24/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.6039 - loss: 0.7594 - val_accuracy: 0.5333 - val_loss: 0.7602
# Epoch 25/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 32s 990ms/step - accuracy: 0.5728 - loss: 0.7557 - val_accuracy: 0.7333 - val_loss: 0.7531
# Epoch 26/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 32s 997ms/step - accuracy: 0.6263 - loss: 0.7496 - val_accuracy: 0.5333 - val_loss: 0.7475
# Epoch 27/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.6267 - loss: 0.7450 - val_accuracy: 0.8000 - val_loss: 0.7397
# Epoch 28/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 32s 989ms/step - accuracy: 0.6542 - loss: 0.7373 - val_accuracy: 0.8000 - val_loss: 0.7327
# Epoch 29/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 949ms/step - accuracy: 0.6398 - loss: 0.7322 - val_accuracy: 0.8000 - val_loss: 0.7257
# Epoch 30/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 835ms/step - accuracy: 0.6528 - loss: 0.7199 - val_accuracy: 0.6000 - val_loss: 0.7126
# Epoch 31/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 843ms/step - accuracy: 0.6504 - loss: 0.7119 - val_accuracy: 0.7333 - val_loss: 0.6970
# Epoch 32/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 843ms/step - accuracy: 0.6709 - loss: 0.7011 - val_accuracy: 0.7333 - val_loss: 0.6824
# Epoch 33/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 844ms/step - accuracy: 0.7035 - loss: 0.6879 - val_accuracy: 0.7333 - val_loss: 0.6693
# Epoch 34/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 937ms/step - accuracy: 0.7104 - loss: 0.6759 - val_accuracy: 0.6667 - val_loss: 0.6658
# Epoch 35/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 28s 855ms/step - accuracy: 0.7061 - loss: 0.6663 - val_accuracy: 0.6667 - val_loss: 0.6431
# Epoch 36/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 843ms/step - accuracy: 0.7147 - loss: 0.6575 - val_accuracy: 0.8000 - val_loss: 0.6396
# Epoch 37/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 843ms/step - accuracy: 0.7294 - loss: 0.6437 - val_accuracy: 0.8000 - val_loss: 0.6257
# Epoch 38/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 856ms/step - accuracy: 0.7289 - loss: 0.6335 - val_accuracy: 0.7333 - val_loss: 0.6202
# Epoch 39/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 848ms/step - accuracy: 0.7206 - loss: 0.6407 - val_accuracy: 0.7333 - val_loss: 0.6062
# Epoch 40/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 28s 867ms/step - accuracy: 0.7409 - loss: 0.6174 - val_accuracy: 0.6667 - val_loss: 0.6981
# Epoch 41/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 847ms/step - accuracy: 0.7147 - loss: 0.6273 - val_accuracy: 0.7333 - val_loss: 0.5911
# Epoch 42/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 843ms/step - accuracy: 0.7510 - loss: 0.6059 - val_accuracy: 0.8000 - val_loss: 0.6106
# Epoch 43/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 844ms/step - accuracy: 0.7398 - loss: 0.6162 - val_accuracy: 0.7333 - val_loss: 0.5781
# Epoch 44/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 834ms/step - accuracy: 0.7523 - loss: 0.6008 - val_accuracy: 0.8000 - val_loss: 0.5950
# Epoch 45/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.7585 - loss: 0.5906 - val_accuracy: 0.8000 - val_loss: 0.5740
# Epoch 46/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 32s 988ms/step - accuracy: 0.7733 - loss: 0.5809 - val_accuracy: 0.7333 - val_loss: 0.5826
# Epoch 47/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.7609 - loss: 0.5782 - val_accuracy: 0.7333 - val_loss: 0.5603
# Epoch 48/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.7692 - loss: 0.5771 - val_accuracy: 0.7333 - val_loss: 0.5537
# Epoch 49/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 950ms/step - accuracy: 0.7666 - loss: 0.5925 - val_accuracy: 0.8000 - val_loss: 0.6176
# Epoch 50/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 850ms/step - accuracy: 0.7785 - loss: 0.5578 - val_accuracy: 0.7333 - val_loss: 0.5799
# Epoch 51/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 854ms/step - accuracy: 0.7723 - loss: 0.5590 - val_accuracy: 0.8000 - val_loss: 0.6246
# Epoch 52/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 853ms/step - accuracy: 0.7534 - loss: 0.5654 - val_accuracy: 0.8000 - val_loss: 0.6049
# Epoch 53/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 841ms/step - accuracy: 0.7684 - loss: 0.5515 - val_accuracy: 0.8000 - val_loss: 0.5307
# Epoch 54/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 844ms/step - accuracy: 0.7732 - loss: 0.5565 - val_accuracy: 0.8000 - val_loss: 0.5511
# Epoch 55/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 851ms/step - accuracy: 0.7729 - loss: 0.5465 - val_accuracy: 0.8000 - val_loss: 0.6015
# Epoch 56/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 844ms/step - accuracy: 0.7790 - loss: 0.5425 - val_accuracy: 0.8000 - val_loss: 0.6033
# Epoch 57/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 845ms/step - accuracy: 0.7904 - loss: 0.5291 - val_accuracy: 0.8000 - val_loss: 0.6772
# Epoch 58/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 853ms/step - accuracy: 0.7812 - loss: 0.5300 - val_accuracy: 0.8000 - val_loss: 0.5953
# Epoch 59/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 28s 864ms/step - accuracy: 0.7936 - loss: 0.5365 - val_accuracy: 0.8000 - val_loss: 0.5579
# Epoch 60/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 849ms/step - accuracy: 0.7879 - loss: 0.5318 - val_accuracy: 0.8000 - val_loss: 0.5476
# Epoch 61/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 840ms/step - accuracy: 0.7809 - loss: 0.5263 - val_accuracy: 0.8000 - val_loss: 0.5568
# Epoch 62/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 849ms/step - accuracy: 0.7860 - loss: 0.5256 - val_accuracy: 0.8000 - val_loss: 0.6718
# Epoch 63/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 848ms/step - accuracy: 0.8008 - loss: 0.5071 - val_accuracy: 0.8667 - val_loss: 0.6274
# Epoch 64/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 853ms/step - accuracy: 0.7918 - loss: 0.5120 - val_accuracy: 0.7333 - val_loss: 0.5907
# Epoch 65/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 28s 875ms/step - accuracy: 0.7935 - loss: 0.5130 - val_accuracy: 0.8000 - val_loss: 0.6380
# Epoch 66/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 857ms/step - accuracy: 0.7947 - loss: 0.5036 - val_accuracy: 0.8667 - val_loss: 0.6082
# Epoch 67/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 855ms/step - accuracy: 0.7992 - loss: 0.5049 - val_accuracy: 0.8000 - val_loss: 0.6045
# Epoch 68/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 853ms/step - accuracy: 0.7997 - loss: 0.5064 - val_accuracy: 0.8000 - val_loss: 0.6011
# Epoch 69/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 28s 867ms/step - accuracy: 0.8110 - loss: 0.4804 - val_accuracy: 0.8000 - val_loss: 0.5292
# Epoch 70/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 934ms/step - accuracy: 0.8070 - loss: 0.4997 - val_accuracy: 0.8667 - val_loss: 0.5587

# %%
figure = plt.figure(figsize=(10, 10))
plt.plot(hist.history['accuracy'], label='Train_accuracy')
plt.plot(hist.history['val_accuracy'], label='Test_accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc="upper left")
plt.show()

figure2 = plt.figure(figsize=(10, 10))
plt.plot(hist.history['loss'], label='Train_loss')
plt.plot(hist.history['val_loss'], label='Test_loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="upper left")
plt.show()

# %%
ypred = model.predict(x_test)
ypred = np.argmax(ypred, axis=1)
y_test_pred = np.argmax(y_test, axis=1)
print(classification_report(y_test_pred, ypred))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.75      0.86         8
#            1       0.78      1.00      0.88         7
#
#     accuracy                           0.87        15
#    macro avg       0.89      0.88      0.87        15
# weighted avg       0.90      0.87      0.87        15

# %%
matrix = confusion_matrix(y_test_pred, ypred)
df_cm = pd.DataFrame(matrix, index=[0, 1], columns=[0, 1])
figure = plt.figure(figsize=(5, 5))
sns.heatmap(df_cm, annot=True, fmt='d')
# Out:
# <Axes: >

# %%
model.save('parkinson_disease_detection.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
labels = ['Healthy', 'Parkinson']
image_healthy = cv2.imread(r'C:\Users\anagh\Downloads\DD\spiral\spiral\testing\healthy\V01HE01.png')
image_parkinson = cv2.imread(r'C:\Users\anagh\Downloads\DD\spiral\spiral\testing\parkinson\V01PE01.png')

image_healthy = cv2.resize(image_healthy, (128, 128))
image_healthy = cv2.cvtColor(image_healthy, cv2.COLOR_BGR2GRAY)
image_healthy = np.array(image_healthy)
image_healthy = np.expand_dims(image_healthy, axis=0)
image_healthy = np.expand_dims(image_healthy, axis=-1)

image_parkinson = cv2.resize(image_parkinson, (128, 128))
image_parkinson = cv2.cvtColor(image_parkinson, cv2.COLOR_BGR2GRAY)
image_parkinson = np.array(image_parkinson)
image_parkinson = np.expand_dims(image_parkinson, axis=0)
image_parkinson = np.expand_dims(image_parkinson, axis=-1)

# %%
ypred_healthy = model.predict(image_healthy)
ypred_parkinson = model.predict(image_parkinson)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %%
figure = plt.figure(figsize=(2, 2))
img_healthy = np.squeeze(image_healthy, axis=0)
plt.imshow(img_healthy)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_healthy[0], axis=0)]}')
plt.show()

# %%
figure = plt.figure(figsize=(2, 2))
image_parkinson = np.squeeze(image_parkinson, axis=0)
plt.imshow(image_parkinson)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_parkinson[0], axis=0)]}')
plt.show()
